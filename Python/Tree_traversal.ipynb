# %% [markdown]
# ## Tree Traversals

# %% [markdown]
# ### Creating the Tree

# %%
class TreeNode:
    def __init__(self,val):
        self.val = val
        self.left = None
        self.right = None

# %%
# nodes
A = TreeNode('A')
B = TreeNode('B')
C = TreeNode('C')
D = TreeNode('D')
E = TreeNode('E')
F = TreeNode('F')


# edges
A.left = B
A.right = C

B.left = D
B.right = E

C.left = F

# %% [markdown]
# ### 1. Pre Order Traversal

# %%
def preorder(node):
    if not node:
        return
    print(node.val,end=' ')
    preorder(node.left)
    preorder(node.right)

# %%
preorder(A)
# Out:
# A B D E C F

# %% [markdown]
# ### 2. In Order Traversal

# %%
def inorder(node):
    if not node:
        return
    inorder(node.left)
    print(node.val, end = ' ')
    inorder(node.right)

# %%
inorder(A)
# Out:
# D B E A F C
